# %% [markdown]
# ## Encoding Test

# %%
import alphapy as ap
from alphapy.nlp import encode_price
import yfinance as yf

# %%
df = yf.download('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.columns = df.columns.str.lower()
df
# Out:
#                                  open        high         low       close  \
# Date
# 1980-12-12 00:00:00-05:00    0.128348    0.128906    0.128348    0.128348
# 1980-12-15 00:00:00-05:00    0.122210    0.122210    0.121652    0.121652
# 1980-12-16 00:00:00-05:00    0.113281    0.113281    0.112723    0.112723
# 1980-12-17 00:00:00-05:00    0.115513    0.116071    0.115513    0.115513
# 1980-12-18 00:00:00-05:00    0.118862    0.119420    0.118862    0.118862
# ...                               ...         ...         ...         ...
# 2023-01-30 00:00:00-05:00  144.960007  145.550003  142.850006  143.000000
# 2023-01-31 00:00:00-05:00  142.699997  144.339996  142.279999  144.289993
# 2023-02-01 00:00:00-05:00  143.970001  146.610001  141.320007  145.429993
# 2023-02-02 00:00:00-05:00  148.899994  151.179993  148.169998  150.820007
# 2023-02-03 00:00:00-05:00  148.029999  157.380005  147.830002  154.500000
#
#                             adj close     volume
# Date
# 1980-12-12 00:00:00-05:00    0.099874  469033600
# 1980-12-15 00:00:00-05:00    0.094663  175884800
# 1980-12-16 00:00:00-05:00    0.087715  105728000
# 1980-12-17 00:00:00-05:00    0.089886   86441600
# 1980-12-18 00:00:00-05:00    0.092492   73449600
# ...                               ...        ...
# 2023-01-30 00:00:00-05:00  143.000000   64015300
# 2023-01-31 00:00:00-05:00  144.289993   65874500
# 2023-02-01 00:00:00-05:00  145.429993   77663600
# 2023-02-02 00:00:00-05:00  150.820007  118339000
# 2023-02-03 00:00:00-05:00  154.500000  154279900
#
# [10626 rows x 6 columns]

# %%
encode_price(df)
# Out:
# 'T0Z0R0V0 L2N0R0V0 L3N0R0V0 H2P0R0V0 H3P0R0V0 H5P0R0V0 H7P0R0V0 H8P0R0V0 H9P0R0V0 H10P0R0V0 H11P0R0V0 L3N0R0V0 L4N0R0V0 H2P0R0V0 L6N0R0V0 L8N0R0V0 L9N0R0V0 L11N0R0V0 H3P0R0V0 L2N0R1V0 L3N0R0V0 H2P0R0V0 H3P0R1V0 L2N0R0V0 H10P1R0V1 L2N0R0V0 H2P0R1V0 H13P0R1V0 L2N0R1V0 L4N0R0V0 L5N0R1V0 L8N1R0V1 L18N1R0V1 L18N1R1V1 L18N1R0V0 H2P1R0V0 H4P1R0V1 H5Z0R1V0 T0P0R0V0 L5N1R1V0 T0Z0R0V0 L18N1R0V0 L18N0R0V0 L18N0R1V0 H2P0R0V0 H6P1R1V0 L3N2R0V1 L18N1R0V1 H2P0R0V0 L18N1R1V0 H4P1R0V0 H5P0R0V0 H7P1R1V0 T0P0R0V0 L3N0R0V0 L4N0R0V0 L5N0R0V0 L6N0R1V0 L18N2R0V1 L18N1R0V1 L18N1R1V1 H2P1R0V2 L2N0R0V2 H5P1R1V1 H7P1R1V1 H9P1R1V1 L2N0R0V1 H2P0R1V0 H18P1R1V0 L2N0R0V0 L3N0R1V0 L5N0R0V0 L8N1R0V0 H2Z0R1V0 L10N0R1V0 L11N0R0V0 H7P2R0V0 H8P0R0V0 L3N0R0V0 L4N0R0V0 H18P1R1V0 H18P0R0V0 H18P0R0V1 T0Z0R0V0 T0Z0R0V0 L6N2R0V1 L11N2R0V1 H2P1R0V1 H4P2R0V1 H18P1R0V0 H18P1R0V2 L2N0R1V1 L3N0R0V1 L5N0R0V1 L6N0R0V0 H3P0R1V0 T0Z0R1V0 L3N0R0V0 L4N0R0V0 L12N1R0V0 H2P0R0V0 H3P0R0V0 L3N1R0V0 H2Z0R2V0 L17N0R2V0 L18N0R1V0 H5P1R2V0 H9P1R1V0 L2N1R0V1 H13P2R1V0 H18P2R0V1 H18P2R1V1 L2N0R0V2 H18P2R0V2 T0Z0R0V2 H18P0R0V2 T0Z0R0V1 L5N2R0V1 H2Z0R1V1 H3P1R0V1 L2N0R0V1 L11N1R0V2 H2P0R0V2 H4P0R1V0 H8P1R0V0 L2N0R0V0 L3N0R0V2 L4N0R0V0 L6N0R0V0 L7N0R1V0 L18N1R0V0 L18N1R0V0 H2P0R1V0 L18N1R1V0 H2P1R0V0 L2N0R1V0 L18N1R1V0 L18N2R0V0 L18N0R0V2 T0Z0R0V0 L18N1R1V0 H2P0R1V0 H6P1R0V0 L18N2R0V0 L18N2R0V1 H2P0R0V1 H3P1R1V0 H5P0R0V0 H6P0R1V0 H7P1R0V0 L4N1R0V0 L5N0R0V1 L8N1R1V0 H2P0R0V1 H3P0R0V0 H6P1R0V0 L2N0R0V0 L4N0R0V0 H3P1R1V0 H4P0R0V0 L2N0R1V0 H12P0R0V1 H13P0R0V0 L2N0R0V0 T0Z0R0V0 T0Z0R0V0 L9N1R1V2 L10N0R0V1 L15N1R0V1 L17N0R1V1 L18N1R1V0 L18N0R1V0 L18N0R1V0 H2P0R0V0 L18N2R1V1 L18N2R0V1 H2P0R0V1 L2N0R0V1 H2P0R0V1 H5P1R0V1 T0Z0R0V1 H8P2R0V1 H11P0R0V0 L3N1R1V1 L4N0R0V0 L7N0R0V0 T0Z0R0V1 H3P0R0V1 L10N0R0V0 L12N1R0V0 L18N0R0V0 L18N0R0V0 L18N0R0V0 H2P0R0V0 H3P0R0V1 L18N2R0V1 L18N0R1V0 L18N0R0V0 L18N2R1V1 T0P0R0V2 H3P1R0V2 H4P0R0V1 T0Z0R0V1 H7P2R0V1 H10P1R1V1 L2N0R0V0 H15P1R1V0 H17P1R0V0 H18P0R1V1 H18P1R0V0 H18Z0R1V1 L5N2R0V0 H2P0R0V0 L2N0R0V0 H4P0R0V0 H18P1R0V0 T0Z0R0V1 L3N0R0V0 L4N1R0V0 T0Z0R0V0 H3P0R1V2 H18P1R0V1 L2N0R0V0 H2P0R0V1 T0Z0R0V0 L3N0R0V0 L7N1R0V0 L18N2R0V0 H2P0R0V0 H3P0R0V0 H4P0R0V0 H5P1R0V0 H7P1R0V1 L5N2R0V0 L7N0R0V0 H3P0R0V1 H4P1R0V0 T0Z0R0V1 H6P0R0V1 L5N1R1V0 L6N0R0V0 H3P0R0V1 H4P1R0V1 L2N0R0V0 T0Z0R0V0 H3P0R0V1 L5N0R0V0 H9P1R0V2 H16P0R0V1 L3N0R1V1 T0P0R0V0 T0Z0R0V0 L3N0R1V1 L13N2R1V0 H2P1R0V0 H18P2R0V1 H18P2R0V1 H18P2R0V1 L2N1R0V1 H2P0R0V1 L4N0R0V0 H2P0R0V0 L7N1R1V0 H2P0R1V0 H5P1R0V0 T0Z0R0V1 L3N0R0V1 L5N1R1V0 L13N0R0V1 L15N2R1V1 H2P1R0V1 L17N1R0V0 L18N0R0V1 L18N0R0V0 H4P1R0V0 H7P1R1V0 H8P0R1V0 L3N0R1V1 H2P0R0V0 H11P0R0V0 H13P0R0V0 L4N0R0V1 L8N1R1V0 H2P0R1V0 H3P1R0V0 H5P0R0V1 L2N0R1V0 H2P0R1V1 T0Z0R0V0 L6N0R0V0 T0Z0R0V1 L18N2R0V0 T0Z0R0V1 H3P0R0V1 L2N0R0V0 H2P0R0V0 L18N1R0V0 H2P0R0V0 H8P0R0V0 L2N0R0V0 L4N0R0V0 L18N0R0V1 H2P0R0V1 L2N0R0V0 T0Z0R0V0 H3P0R0V1 T0Z0R0V1 T0Z0R1V0 L18N1R0V1 L18N2R0V1 L18N0R0V1 H2P0R1V1 L18N1R1V2 H2Z0R1V0 L18N2R0V1 L18N0R0V1 L18N0R0V1 L18N2R0V1 H4P2R0V1 H10P2R0V1 H12P2R0V1 L2N0R0V1 L3N2R0V1 L5N0R0V1 L6N0R0V1 H3P0R0V1 H5P0R0V1 T0Z0R0V0 H8P1R0V1 T0Z0R0V1 T0Z0R0V1 L4N0R0V1 L5N0R0V0 H2P0R0V0 L2N0R1V0 L17N2R0V1 H2P0R0V1 H3P0R0V2 H4P1R0V1 L2N0R1V0 L18N2R0V1 L18N0R0V1 L18N0R0V0 T0Z0R0V0 H4P1R0V0 L18N1R0V0 L18N1R0V1 T0Z0R0V1 H3P0R0V2 H4P1R0V0 H6P1R0V0 L2N0R1V0 H13P1R0V0 H14P0R0V0 L2N0R0V0 L4N1R0V1 L8N1R0V0 H2P0R0V0 L11N1R1V1 L18N0R0V0 L18N0R0V1 L18N0R0V0 H2P0R0V0 H4P0R0V0 H5P0R0V0 T0Z0R0V0 L3N0R0V0 L6N0R0V0 T0Z0R0V0 L18N0R0V0 H2P1R0V0 L18N1R1V0 L18N1R0V0 T0Z0R0V0 L18N0R0V0 L18N1R0V0 H2P0R0V0 H6P2R0V1 T0Z0R0V0 T0Z0R0V0 T0Z0R0V1 L5N1R0V0 L6N1R1V0 T0Z0R0V0 H13P2R1V0 H15P1R1V1 T0Z0R0V1 L4N2R0V0 L5N0R0V0 L14N1R0V1 T0Z0R0V1 L18N0R0V1 L18N2R0V1 L18N2R0V2 T0Z0R0V0 L18N2R0V2 H2P1R0V2 H5P1R0V1 H7P2R0V2 H8P0R1V1 H10P0R0V1 H14P1R0V1 H16P0R0V1 H18P2R0V0 T0Z0R0V1 H18P0R0V0 L4N0R0V0 L5N1R0V0 T0Z0R0V0 L9N1R0V0 H2P1R0V0 H3P0R0V0 H6P1R0V1 L4N2R0V1 L5N0R0V1 L17N1R0V1 L18N0R0V1 H2P0R0V0 H6P2R0V1 H7P0R1V1 L2N0R1V0 T0Z0R1V0 H10P0R1V0 H18P2R1V0 T0Z0R0V2 H2P0R0V0 H18P1R0V0 H18P1R0V1 H18P2R0V2 H18P2 ...
